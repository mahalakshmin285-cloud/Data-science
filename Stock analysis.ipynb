# %% [markdown]
# Tesla Stock Price Financial Analysis

# %% [markdown]
# Data Analysis day 1 useing pandas  and matplotlib

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import the data 
data =pd.read_csv(r"c:\Users\User\Downloads\TSLA.csv")

# %%
#show the data 
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %%
data.set_index('Date')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...                ...         ...         ...         ...         ...
# 2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#               Volume
# Date
# 2010-06-29  18766300
# 2010-06-30  17187100
# 2010-07-01   8218800
# 2010-07-02   5139800
# 2010-07-06   6866900
# ...              ...
# 2020-01-28  11788500
# 2020-01-29  17801500
# 2020-01-30  29005700
# 2020-01-31  15719300
# 2020-02-03  47065000
#
# [2416 rows x 6 columns]

# %%
#plot  stock data by line Graph 
plt.figure(figsize=(9,7))
data['Close'].plot()
plt.show()

# %%
df_close = data['Close']
plt.figure(figsize=(9,7))
df_close.plot(style='k.')
plt.title('Scatter plot of closing price')
plt.show()

# %% [markdown]
# create new colume of price differnce

# %%
data['price_diff']=data['Close'].shift(-1)
data['price_diff']
# Out:
# 0        23.830000
# 1        21.959999
# 2        19.200001
# 3        16.110001
# 4        15.800000
#            ...
# 2411    580.989990
# 2412    640.809998
# 2413    650.570007
# 2414    780.000000
# 2415           NaN
# Name: price_diff, Length: 2416, dtype: float64

# %% [markdown]
# create new colume for daily return

# %%
data['daily_rn']=data['price_diff']/data['Close']
data['daily_rn']
# Out:
# 0       0.997489
# 1       0.921527
# 2       0.874317
# 3       0.839063
# 4       0.980757
#           ...
# 2411    1.024854
# 2412    1.102962
# 2413    1.015231
# 2414    1.198949
# 2415         NaN
# Name: daily_rn, Length: 2416, dtype: float64

# %%
data['ra50']=data['Close'].rolling(50).mean()
plt.figure(figsize=(9,7))
data['ra50'].plot()
data['Close'].plot()
plt.legend()
plt.show()

# %%
data['ra50']=data['Close'].rolling(50).mean()
data['ra10']=data['Close'].rolling(10).mean()

# %%
data=data.dropna()
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 49    2010-09-08   20.660000   20.950001   20.600000   20.900000   20.900000
# 50    2010-09-09   21.000000   21.049999   20.690001   20.709999   20.709999
# 51    2010-09-10   20.750000   20.930000   19.760000   20.170000   20.170000
# 52    2010-09-13   20.889999   20.900000   20.500000   20.719999   20.719999
# 53    2010-09-14   20.540001   21.600000   20.530001   21.120001   21.120001
# ...          ...         ...         ...         ...         ...         ...
# 2410  2020-01-27  541.989990  564.440002  539.280029  558.020020  558.020020
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
#
#         Volume  price_diff  daily_rn        ra50        ra10
# 49      288400   20.709999  0.990909   19.833600   20.270000
# 50      376200   20.170000  0.973926   19.770000   20.351000
# 51      386600   20.719999  1.027268   19.696800   20.393000
# 52      360800   21.120001  1.019305   19.672000   20.495000
# 53      654700   21.980000  1.040720   19.710400   20.620000
# ...        ...         ...       ...         ...         ...
# 2410  13608100  566.900024  1.015913  414.357601  541.707001
# 2411  11788500  580.989990  1.024854  418.773402  545.911005
# 2412  17801500  640.809998  1.102962  423.406202  550.218005
# 2413  29005700  650.570007  1.015231  429.179001  562.449005
# 2414  15719300  780.000000  1.198949  435.190602  576.157007
#
# [2366 rows x 11 columns]

# %%
data['Shares'] = [1 if data.loc[ei, 'ra10']>data.loc[ei, 'ra50'] else 0 for ei in data.index]
print(data['Shares'])
# Out:
# 49      1
# 50      1
# 51      1
# 52      1
# 53      1
#        ..
# 2410    1
# 2411    1
# 2412    1
# 2413    1
# 2414    1
# Name: Shares, Length: 2366, dtype: int64
# C:\Users\User\AppData\Local\Temp\ipykernel_16852\602134388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Shares'] = [1 if data.loc[ei, 'ra10']>data.loc[ei, 'ra50'] else 0 for ei in data.index]

# %%
#calculate profit
data['Close1'] = data['Close'].shift(-1)
data['Profit'] = [data.loc[ei, 'Close1'] - data.loc[ei, 'Close'] if data.loc[ei, 'Shares']==1 else 0 for ei in data.index]
data['Profit'].plot()
print(data['Close1'])
print(data['Profit'])
plt.axhline(y=0, color='red')
# Out:
# 49       20.709999
# 50       20.170000
# 51       20.719999
# 52       21.120001
# 53       21.980000
#            ...
# 2410    566.900024
# 2411    580.989990
# 2412    640.809998
# 2413    650.570007
# 2414           NaN
# Name: Close1, Length: 2366, dtype: float64
# 49      -0.190001
# 50      -0.539999
# 51       0.549999
# 52       0.400002
# 53       0.859999
#           ...
# 2410     8.880004
# 2411    14.089966
# 2412    59.820008
# 2413     9.760009
# 2414          NaN
# Name: Profit, Length: 2366, dtype: float64
# C:\Users\User\AppData\Local\Temp\ipykernel_16852\3718423141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Close1'] = data['Close'].shift(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_16852\3718423141.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Profit'] = [data.loc[ei, 'Close1'] - data.loc[ei, 'Close'] if data.loc[ei, 'Shares']==1 else 0 for ei in data.index]

# %%
data['log_return']=np.log(data['Close'].shift(-1))-np.log(data['Close'])
data['log_return']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16852\1058313656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['log_return']=np.log(data['Close'].shift(-1))-np.log(data['Close'])
# 49     -0.009133
# 50     -0.026420
# 51      0.026903
# 52      0.019121
# 53      0.039912
#           ...
# 2410    0.015788
# 2411    0.024551
# 2412    0.097999
# 2413    0.015116
# 2414         NaN
# Name: log_return, Length: 2366, dtype: float64

# %%
from scipy.stats import norm
mu = data['log_return'].mean()
sigma = data['log_return'].std()

density = pd.DataFrame()
density['x'] = np.arange(data['log_return'].min()-0.01, data['log_return'].max()+0.01, 0.001)
density['pdf'] = norm.pdf(density['x'], mu, sigma)

data['log_return'].hist(bins=50, figsize=(9, 8))
plt.plot(density['x'], density['pdf'], color='red')
plt.show()

# %%
prob_return1 = norm.cdf(-0.10, mu, sigma)
print('The probability of dropping over 10% in one day ', prob_return1)
# Out:
# The probability of dropping over 10% in one day  0.00072723221548091

# %%
mu220 = 365*mu
sigma220 = (365**0.5) * sigma
drop20 = None
print('The probability of dropping over 25% over a year: ', drop20)
# Out:
# The probability of dropping over 25% over a year:  None

# %%
from pandas.plotting import scatter_matrix
sm = scatter_matrix(data, figsize=(9, 7))
